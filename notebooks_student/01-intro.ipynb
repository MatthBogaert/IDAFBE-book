# %% [markdown]
# # Chapter 1: Introduction
#
# **Task:** Write a function that computes the sine of an array of values and plot it.

# %%
import numpy as np

# TODO: create an array x from 0 to 10 with 100 points
# TODO: compute y = sin(x)
# TODO: plot x vs y
